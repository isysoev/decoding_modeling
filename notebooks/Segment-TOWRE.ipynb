# %%
import os

# %%
import math

# %%
from collections import defaultdict

# %%
# -*- coding: utf-8 -*-

import codecs

def get_basic_phoneme(phoneme):
	if phoneme[-1].isdigit():
		return phoneme[:-1]
	return phoneme

def get_phonemes(phonemes_code):
	return tuple([get_basic_phoneme(phoneme_code) for phoneme_code in phonemes_code.split(';')])

def get_pg_pair(pg_pair_code):
	phonemes_code, grapheme = pg_pair_code.split('>')
	return (get_phonemes(phonemes_code), grapheme)

def get_mapping(mapping_code):
	return tuple([get_pg_pair(pg_pair_code) for pg_pair_code in mapping_code.split('|')])

def read_phonix(input_file_name):
	phonix = []
	with codecs.open(input_file_name, encoding = 'utf-8') as input_file:
		for line in input_file:
			line = line.strip()
			if not line: continue
			word, mapping_code = line.split(' ')
			phonix.append((word, get_mapping(mapping_code)))
	return phonix

def pg_pair_to_str(pg_pair):
	phonemes, grapheme = pg_pair
	return '%s>%s' % (';'.join(phonemes), grapheme)

def mapping_to_str(mapping):
	return '|'.join(pg_pair_to_str(pg_pair) for pg_pair in mapping)

# %%
def read_freq_list(freq_file_name):
    wordfreqs = {}
    with open(freq_file_name) as input_file:
        for line in input_file:
            line = line.strip()
            word, freq = line.split(' ')
            freq = float(freq)
            wordfreqs[word] = freq
    return wordfreqs

# %%
phonix = read_phonix('../data/phonix.txt')
phonix_dict = dict(phonix)
wordfreqs = read_freq_list('../data/word-freqs.txt')

# %%
def normalize(distr):
    denominator = sum(distr.values())
    return {key: float(value) / denominator for key, value in distr.items()}

# %%
def get_pg_freqs(wordfreqs, phonix):
    aggregator = defaultdict(float)
    for word, mapping in phonix:
        if word not in wordfreqs: continue
        wordfreq = wordfreqs[word]
        for pg in mapping:
            aggregator[pg_pair_to_str(pg)] += wordfreq
    return normalize(aggregator)

# %%
pg_freqs = get_pg_freqs(wordfreqs, phonix)

# %%
pg_logfreqs = {pg: math.log(freq) for pg, freq in pg_freqs.items()}

# %%
class LList:
    def __init__(self, *args):
        if 0 == len(args):
            self._tip = None
            self._prefix = None
            self._len = 0
        elif 1 == len(args):
            self._tip = args[0]
            self._prefix = LList()
            self._len = 1
        else:
            self._tip = args[1]
            self._prefix = args[0]
            self._len = 1 + len(self._prefix)

    def tip(self):
        return self._tip

    def prefix(self):
        return self._prefix

    def nil(self):
        return self._len == 0

    def __len__(self):
        return self._len

    def toPy(self):
        if self.nil(): return []
        pylist = self._prefix.toPy()
        pylist.append(self._tip)
        return pylist

# %%
def possibleSegmentations(sequence, cutoff_len):
    if 0 == len(sequence): return []
    segmentationColumn = [LList(LList(sequence[0]))]
    for i in range(1, len(sequence)):
        newSegmentationColumn = []
        symI = sequence[i]
        for segmentation in segmentationColumn:
            newSegmentationColumn.append(LList(segmentation, LList(symI)))
            if len(segmentation.tip()) < cutoff_len:
                newSegmentationColumn.append(LList(segmentation.prefix(), LList(segmentation.tip(), symI)))
        segmentationColumn = newSegmentationColumn
    return [[subsequence.toPy() for subsequence in segmentation.toPy()] for segmentation in segmentationColumn]

def assortSegmentations(segmentations):
    sorter = defaultdict(list)
    for segmentation in segmentations:
        sorter[len(segmentation)].append(segmentation)
    return sorter

def possibleAlignments(word, phonemes, w_cutoff = 4, p_cutoff = 3):
    return _possibleAlignments(possibleSegmentations(word, w_cutoff),
                               possibleSegmentations(phonemes, p_cutoff),
                               word, phonemes)

def _possibleAlignments(letrSegs, phSegs, word, phonemes):
    assortedLetrSegs = assortSegmentations(letrSegs)
    assortedPhSegs = assortSegmentations(phSegs)
    alignments = []
    for i in range(1, min(len(word), len(phonemes)) + 1):
        letrSegsI = [["".join(grp) for grp in segmentation]
                     for segmentation in assortedLetrSegs.get(i, [])]
        phSegsI = [[tuple(grp) for grp in segmentation]
                     for segmentation in assortedPhSegs.get(i, [])]
        for letrSeg in letrSegsI:
            for phSeg in phSegsI:
                alignments.append(list(zip(phSeg, letrSeg)))
    return alignments

# %%
TOWRE_FOLDER = '../data/TOWRE'
def readTowre():
    word_pronunciations = {}
    for towre_file in os.listdir(TOWRE_FOLDER):
        if not towre_file.endswith('.csv'): continue
        with open(os.path.join(TOWRE_FOLDER, towre_file)) as infile:
            for i, line in enumerate(infile):
                if 0 == i: continue
                line = line.strip()
                cells = line.split(',')
                word = cells[0].strip()
                pronunciations = []
                for pronunciation_record in cells[1:]:
                    pronunciation_record = pronunciation_record.strip()
                    if not pronunciation_record: continue
                    pronunciations.append(pronunciation_record.split('/'))
                word_pronunciations[word] = pronunciations
    return word_pronunciations

# %%
word_pronunciations = readTowre()

# %%
word_pronunciations['trisk']
# Out:
# [['t', 'r', 'ɪ', 's', 'k']]

# %%
possibleAlignments('jeltlic', word_pronunciations['jeltlic'][0])
# Out:
# [[(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'el'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'el'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l', 'ɪ'), 'el'), (('c',), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'elt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'elt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'elt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'elt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'elt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l', 'ɪ'), 'elt'), (('c',), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'eltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'eltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'eltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'eltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'eltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l', 'ɪ'), 'eltl'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l', 't'), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't'), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l',), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l',), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'e'), (('ɪ',), 'l'), (('c',), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l',), 'l'), (('ɪ', 'c'), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l', 'ɪ'), 'l'), (('c',), 'tlic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'e'), (('ɪ',), 'l'), (('c',), 'tlic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't'), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't', 'l'), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t',), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l'), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l',), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t',), 'lt'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l'), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l',), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'e'), (('ɪ',), 'lt'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l',), 'lt'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l', 'ɪ'), 'lt'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'e'), (('ɪ',), 'lt'), (('c',), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't'), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't', 'l'), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t',), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l'), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l',), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t',), 'ltl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l'), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l',), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'e'), (('ɪ',), 'ltl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l',), 'ltl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l', 'ɪ'), 'ltl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'e'), (('ɪ',), 'ltl'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't'), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'e'), (('l', 't', 'l'), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t',), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l'), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'e'), (('t', 'l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l',), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'e'), (('l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t',), 'ltli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l'), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'e'), (('t', 'l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l',), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'e'), (('l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'e'), (('ɪ',), 'ltli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l',), 'ltli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'e'), (('l', 'ɪ'), 'ltli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'e'), (('ɪ',), 'ltli'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't'), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t',), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t',), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'el'), (('ɪ',), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'el'), (('ɪ',), 't'), (('c',), 'lic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't'), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t',), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t',), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'el'), (('ɪ',), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'el'), (('ɪ',), 'tl'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't'), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'el'), (('l', 't', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t',), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'el'), (('t', 'l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'el'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t',), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'el'), (('t', 'l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'el'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'el'), (('ɪ',), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'el'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'el'), (('ɪ',), 'tli'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'elt'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'elt'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'elt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'elt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'elt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'elt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'elt'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'elt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'elt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'elt'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'j'), (('ɛ',), 'elt'), (('l', 't'), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'elt'), (('l', 't', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'elt'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'elt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'elt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'elt'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'elt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'elt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'elt'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'elt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'elt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'elt'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'eltl'), (('l', 't'), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ',), 'eltl'), (('l', 't', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'eltl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'eltl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l'), 'eltl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'eltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'), (('ɛ', 'l', 't'), 'eltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'eltl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'eltl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l',), 'eltl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'eltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't'), 'eltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'), (('l', 't', 'l'), 'eltl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'eltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t',), 'eltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'), (('t', 'l'), 'eltl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't'), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t',), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t',), 't'), (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l'), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'l'), (('ɪ',), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l',), 't'), (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l', 'ɪ'), 't'), (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'l'), (('ɪ',), 't'), (('c',), 'lic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't'), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t',), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t',), 'tl'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l'), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'l'), (('ɪ',), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l',), 'tl'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l', 'ɪ'), 'tl'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'l'), (('ɪ',), 'tl'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't'), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'l'), (('l', 't', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t',), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'l'), (('t', 'l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t',), 'tli'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l'), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'l'), (('t', 'l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'l'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'l'), (('ɪ',), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l',), 'tli'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'l'), (('l', 'ɪ'), 'tli'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'l'), (('ɪ',), 'tli'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'lt'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'lt'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'lt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'lt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'lt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'lt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'lt'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'lt'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'lt'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'lt'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'je'), (('ɛ',), 'lt'), (('l', 't'), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'lt'), (('l', 't', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'lt'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'lt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'lt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'lt'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'lt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'lt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'lt'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'lt'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'lt'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'lt'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'ltl'), (('l', 't'), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ',), 'ltl'), (('l', 't', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'ltl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'ltl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l'), 'ltl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'ltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'), (('ɛ', 'l', 't'), 'ltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'ltl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'ltl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l',), 'ltl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'ltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't'), 'ltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'), (('l', 't', 'l'), 'ltl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'ltl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t',), 'ltl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'), (('t', 'l'), 'ltl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ',), 't'), (('l', 't'), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ',), 't'), (('l', 't', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 't'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 't'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t',), 'l'), (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t', 'l'), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t', 'l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 't'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 't'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 't'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 't'), (('l',), 'l'), (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 't'), (('l', 'ɪ'), 'l'), (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 't'), (('ɪ',), 'l'), (('c',), 'ic')],
#  [(('dʒ',), 'jel'), (('ɛ',), 't'), (('l', 't'), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ',), 't'), (('l', 't', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 't'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 't'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 't'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t',), 'li'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t', 'l'), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 't'), (('t', 'l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 't'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 't'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 't'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 't'), (('l',), 'li'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 't'), (('l', 'ɪ'), 'li'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 't'), (('ɪ',), 'li'), (('c',), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ',), 'tl'), (('l', 't'), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ',), 'tl'), (('l', 't', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 'tl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 'tl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l'), 'tl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 'tl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'), (('ɛ', 'l', 't'), 'tl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 'tl'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 'tl'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l',), 'tl'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 'tl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't'), 'tl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'), (('l', 't', 'l'), 'tl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 'tl'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t',), 'tl'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'), (('t', 'l'), 'tl'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ',), 'l'), (('l', 't'), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ',), 'l'), (('l', 't', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l'), 'l'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l'), 'l'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l'), 'l'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l', 't'), 'l'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jelt'), (('ɛ', 'l', 't'), 'l'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l',), 'l'), (('t',), 'i'), (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l',), 'l'), (('t', 'l'), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l',), 'l'), (('t', 'l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't'), 'l'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't'), 'l'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jelt'), (('l', 't', 'l'), 'l'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t',), 'l'), (('l',), 'i'), (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t',), 'l'), (('l', 'ɪ'), 'i'), (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jelt'), (('t', 'l'), 'l'), (('ɪ',), 'i'), (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ', 'c'), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ', 'c'), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 't'),
#   (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 't'),
#   (('c',), 'lic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 'tl'),
#   (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 'tl'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 'tl'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tl'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tl'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tl'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 'tli'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 'tli'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 'tli'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tli'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tli'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'l'),
#   (('ɪ',), 'tli'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t',), 'l'),
#   (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t', 'l'), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t', 'l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'lt'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'lt'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'lt'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'lt'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t',), 'li'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t', 'l'), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t', 'l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'lt'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'lt'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'lt'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'lt'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'lt'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'ltl'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'ltl'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'ltl'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'ltl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'ltl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't', 'l'), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'ltl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'ltl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t', 'l'), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'e'),
#   (('l',), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'ltl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'ltl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t', 'l'), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'e'),
#   (('l',), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'e'),
#   (('l',), 'ltl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t', 'l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t',), 'li'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t', 'l'), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t', 'l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'el'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 'tl'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 'tl'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 'tl'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'el'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'el'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'el'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l',), 'l'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l',), 'l'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l', 't'), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'elt'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'elt'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'elt'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'elt'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l', 't'), 'elt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'elt'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'elt'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'elt'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l', 't'), 'elt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'j'),
#   (('t',), 'elt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t', 'l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ', 'l'), 'je'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t',), 'li'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t', 'l'), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t', 'l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 'tl'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 'tl'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 'tl'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l', 't'), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l', 't'), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'),
#   (('t',), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l',), 'l'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l',), 'l'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l', 't'), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'lt'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'lt'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'lt'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'lt'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l', 't'), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'lt'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'lt'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'lt'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l', 't'), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'je'),
#   (('t',), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l',), 'l'),
#   (('t',), 'i'),
#   (('l', 'ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l',), 'l'),
#   (('t', 'l'), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l',), 'l'),
#   (('t', 'l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l', 't'), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l', 't'), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ',), 't'),
#   (('l', 't', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ', 'l'), 't'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ', 'l'), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ', 'l'), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'jel'),
#   (('ɛ', 'l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'),
#   (('l',), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'jel'),
#   (('l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ', 'l'), 'jel'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ', 'c'), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'l'),
#   (('c',), 'ic')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'li'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l', 'ɪ'), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 't'),
#   (('ɪ',), 'li'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 'tl'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 'tl'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t', 'l'), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'l'),
#   (('l',), 'tl'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'lt'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l', 't'), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'e'),
#   (('t',), 'lt'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l',), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'el'),
#   (('l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ', 'l'), 'el'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'j'),
#   (('l',), 'el'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l',), 'i'),
#   (('ɪ', 'c'), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t',), 'l'),
#   (('l', 'ɪ'), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l',), 't'),
#   (('t', 'l'), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ',), 'l'),
#   (('l', 't'), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'je'),
#   (('ɛ', 'l'), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ', 'ɛ'), 'je'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')],
#  [(('dʒ',), 'j'),
#   (('ɛ',), 'e'),
#   (('l',), 'l'),
#   (('t',), 't'),
#   (('l',), 'l'),
#   (('ɪ',), 'i'),
#   (('c',), 'c')]]

# %%
def alignmentScore(alignment):
    score = 0
    for pg in alignment:
        pg_str = pg_pair_to_str(pg)
        pg_score = pg_logfreqs.get(pg_str, None)
        if pg_score is None: return None
        score += pg_score
    return score

# %%
def bestAlignment(word, pronunciation):
    alignments = possibleAlignments(word, pronunciation)
    valid_alignments = []
    scores = []
    for alignment in alignments:
        score = alignmentScore(alignment)
        if score is not None:
            valid_alignments.append(alignment)
            scores.append(score)
    if not valid_alignments:
        print("No alignment between %s and %s" % (word, ';'.join(pronunciation)))
        return None
    best_idx = max(range(len(scores)), key = lambda i: scores[i])
    return valid_alignments[best_idx]

# %%
bestAlignment('happ', "h;æ;pp".split(';'))
# Out:
# No alignment between happ and h;æ;pp

# %%
def genTOWREphonix(word_pronunciations):
    phonix = []
    for word, pronunciations in word_pronunciations.items():
        for i, pronunciation in enumerate(pronunciations):
            alignment = bestAlignment(word, pronunciation)
            if alignment is not None:
                phonix.append((word if 1 == len(pronunciations) else "%s(%d)" % (word, i), alignment))
    return phonix

# %%
towre_phonix = genTOWREphonix(word_pronunciations)
# Out:
# No alignment between bevignuf and b;ɪ;v;ʌ;g;n;ʌ;f
# No alignment between bevignuf and b;ɛ;v;ʌ;g;n;ʌ;f
# No alignment between vuntilorst and v;ʌ;n;t;ʌ;l;ɝ;s;t
# No alignment between vuntilorst and v;ʌ;n;t;æ;l;ɝ;s;t
# No alignment between crolnadibot and k;r;ɔ;l;n;ɛ;d;æ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɔ;l;n;æ;d;ʌ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɑ;l;n;æ;d;æ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɑ;l;n;ɛ;d;ʌ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɔ;l;n;æ;d;æ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɔ;l;n;ɛ;d;ʌ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɑ;l;n;ɛ;d;æ;b;ɑ;t
# No alignment between crolnadibot and k;r;ɑ;l;n;æ;d;ʌ;b;ɑ;t
# No alignment between happon and h;æ;p;ɛ;n
# No alignment between morlingdon and m;ɝ;l;i;ŋ;d;ɛ;n
# No alignment between revignuf and r;i;v;ə;g;n;ʌ;f
# No alignment between revignuf and r;ɛ;v;ə;g;n;ʌ;f
# No alignment between strilmolifant and s;t;r;ɪ;l;m;oʊ;l;ʌ;f;æ;n;t
# No alignment between strilmolifant and s;t;r;ɪ;l;m;ɑ;l;ʌ;f;æ;n;t

# %%
towre_phonix[2]
# Out:
# ('amalfitut(1)',
#  [(('ʌ',), 'a'),
#   (('m',), 'm'),
#   (('ɑ',), 'a'),
#   (('l',), 'l'),
#   (('f',), 'f'),
#   (('ɪ',), 'i'),
#   (('t',), 't'),
#   (('ʌ',), 'u'),
#   (('t',), 't')])

# %%
def output_phonix(phonix, outfname):
    phonix.sort(key = lambda entry: entry[0])
    with codecs.open(outfname, 'w', encoding = 'utf-8') as outfile:
        for word, mapping in phonix:
            print('%s %s' % (word, mapping_to_str(mapping)), file=outfile)

# %%
output_phonix(towre_phonix, '../data/towre_phonix.txt')

# %%
pg_freqs['ɛ>o']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-03ea1fc76fe2> in <module>
# ----> 1 pg_freqs['ɛ>o']
#
# KeyError: 'ɛ>o'

# %%
tʃ
